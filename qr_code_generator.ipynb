# %%
from src.utils import generate_onboarding_payload

# %%
#! Set Watch Survey Title and URL in Module...

id_participant = "test_participant_007"
id_experiment = "cbe_2025_mattress_pad_study"
id_password = "1G8yOhPvMZ6xx"

generate_onboarding_payload(id_participant, id_experiment, id_password)
# Out:
# cozie://param?data=...
# Number of characters: 1607 of 2048 characters ( 78 %)
